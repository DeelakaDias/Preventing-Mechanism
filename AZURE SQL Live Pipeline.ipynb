# %% [markdown]
# #### Install the Azure Connector

# %%
# pip install pyodbc pandas

# %% [markdown]
# #### The Live Pipeline Cod

# %%
import pyodbc
import pandas as pd

print("🔌 Initiating Azure Connection Pipeline...")

# 1. YOUR AZURE CREDENTIALS

server = 'kreseakreiotprdsrv.database.windows.net'
database = 'KRESEAKREIOTPRD'
username = 'IOTAdmin'
password = 'oKuvodump5JNG7dM'
table_name = 'MBP_ControllerData' 

# The standard Microsoft driver for connecting to SQL databases
driver = '{ODBC Driver 17 for SQL Server}' 

# Build the secure connection key
connection_string = f'DRIVER={driver};SERVER={server};PORT=1433;DATABASE={database};UID={username};PWD={password}'

# 2. TEST THE CONNECTION & FETCH DATA

try:
    print("Attempting to securely connect to Azure PRD environment...")
    conn = pyodbc.connect(connection_string)
    print("✅ CONNECTION SUCCESSFUL!\n")
    
    # Write the SQL query to grab only the absolute newest row
    query =         query = f"""
            SELECT TOP 5 * FROM {'MBP_ControllerData'} 
            WHERE machineSerialNumber = '{'0521760'}' 
            ORDER BY dateTime DESC
        """
    
    print(f"Fetching the latest record from [{table_name}]...")
    latest_record = pd.read_sql(query, conn)
    
    conn.close()

    # 3. PRINT THE RESULTS

    if not latest_record.empty:
        print("\n🎉 LATEST RECORD FOUND:\n")
        pd.set_option('display.max_columns', None)
        print(latest_record)
        print("\nPipeline test complete. Data is flowing beautifully.")
    else:
        print(f"⚠️ Connection worked, but the table [{table_name}] is empty!")

except pyodbc.Error as db_error:
    print(f"\n❌ AZURE DATABASE ERROR:")
    print("Please check your server name, username, password, or firewall settings.")
    print(f"Technical details: {db_error}")
except Exception as e:
    print(f"\n❌ PYTHON ERROR: {e}")
# Out:
# 🔌 Initiating Azure Connection Pipeline...
# Attempting to securely connect to Azure PRD environment...
# ✅ CONNECTION SUCCESSFUL!
#
# Fetching the latest record from [MBP_ControllerData]...
# C:\Users\deela\AppData\Local\Temp\ipykernel_16880\2810112201.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   latest_record = pd.read_sql(query, conn)
# 🎉 LATEST RECORD FOUND:
#
#        Id  machineRPM                                   machineVibration  \
# 0  289493         0.0  10,646,20,880,30,1240,40,9863,50,511,60,803,70...
# 1  289492         0.0  10,668,20,641,30,782,40,1369,50,1115,60,1220,7...
# 2  289491         0.0  10,674,20,870,30,706,40,1650,50,2612,60,5734,7...
# 3  289490         0.0  10,660,20,907,30,518,40,911,50,1162,60,1175,70...
# 4  289489         0.0  10,490,20,364,30,314,40,959,50,1207,60,512,70,...
#
#    needleRuntime                dateTime machineSerialNumber   status  \
# 0         3439.0 2026-03-10 05:55:05.592             0521760  Running
# 1         3660.0 2026-03-10 05:55:02.016             0521760  Running
# 2         3285.0 2026-03-10 05:54:54.961             0521760  Running
# 3         2822.0 2026-03-10 05:54:40.392             0521760  Running
# 4         1594.0 2026-03-10 05:54:27.528             0521760  Running
#
#    machineVoltageMean  machineVoltageMin  machineVoltageMax  \
# 0          234.181793         233.847046         234.555954
# 1          233.526611         232.872223         234.380127
# 2          234.129334         233.573990         234.826889
# 3          232.638611         231.995651         233.850723
# 4          232.338348         231.745499         232.992203
#
#    machineCurrentMean  machineCurrentMin  machineCurrentMax  machinePowerMean  \
# 0            1.231436           0.249143           1.528222        288.379922
# 1            2.501269           0.393667           3.318764        584.112842
# 2            2.189669           0.375400           2.856773        512.665663
# 3            3.138261           0.173495           5.032499        730.080698
# 4            1.718251           0.199213           3.442569        399.215625
#
#    machinePowerMin  machinePowerMax      epochT
# 0        58.261436       358.453645  1773122105
# 1        91.674189       777.852265  1773122101
# 2        87.683608       670.847149  1773122094
# 3        40.250157      1176.853493  1773122080
# 4        46.166819       802.091850  1773122067
#
# Pipeline test complete. Data is flowing beautifully.
