# %% [markdown]
# #### Install the Azure Connector

# %%
pip install pyodbc pandas
# Out:
# Requirement already satisfied: pyodbc in c:\users\deelakad\appdata\local\anaconda3\lib\site-packages (5.2.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in c:\users\deelakad\appdata\local\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\deelakad\appdata\local\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\deelakad\appdata\local\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\deelakad\appdata\local\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\deelakad\appdata\local\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\deelakad\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# #### The Live Pipeline Cod

# %%
import pyodbc
import pandas as pd

print("🔌 Initiating Azure Connection Pipeline...")

# ---------------------------------------------------------
# 1. YOUR AZURE CREDENTIALS
# ---------------------------------------------------------
server = 'kreseakreiotprdsrv.database.windows.net'
database = 'KRESEAKREIOTPRD'
username = 'IOTAdmin'
password = 'oKuvodump5JNG7dM'
table_name = 'MBP_ControllerData' 

# The standard Microsoft driver for connecting to SQL databases
driver = '{ODBC Driver 17 for SQL Server}' 

# Build the secure connection key
connection_string = f'DRIVER={driver};SERVER={server};PORT=1433;DATABASE={database};UID={username};PWD={password}'

# ---------------------------------------------------------
# 2. TEST THE CONNECTION & FETCH DATA
# ---------------------------------------------------------
try:
    print("Attempting to securely connect to Azure PRD environment...")
    conn = pyodbc.connect(connection_string)
    print("✅ CONNECTION SUCCESSFUL!\n")
    
    # Write the SQL query to grab only the absolute newest row
    query = f"SELECT TOP 1 * FROM {table_name} ORDER BY Id DESC"
    
    print(f"Fetching the latest record from [{table_name}]...")
    latest_record = pd.read_sql(query, conn)
    
    conn.close()
    
    # ---------------------------------------------------------
    # 3. PRINT THE RESULTS
    # ---------------------------------------------------------
    if not latest_record.empty:
        print("\n🎉 LATEST RECORD FOUND:\n")
        pd.set_option('display.max_columns', None)
        print(latest_record)
        print("\nPipeline test complete. Data is flowing beautifully.")
    else:
        print(f"⚠️ Connection worked, but the table [{table_name}] is empty!")

except pyodbc.Error as db_error:
    print(f"\n❌ AZURE DATABASE ERROR:")
    print("Please check your server name, username, password, or firewall settings.")
    print(f"Technical details: {db_error}")
except Exception as e:
    print(f"\n❌ PYTHON ERROR: {e}")
# Out:
# 🔌 Initiating Azure Connection Pipeline...
# Attempting to securely connect to Azure PRD environment...
# ✅ CONNECTION SUCCESSFUL!
#
# Fetching the latest record from [MBP_ControllerData]...
# C:\Users\DeelakaD\AppData\Local\Temp\ipykernel_5032\3700833480.py:33: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   latest_record = pd.read_sql(query, conn)
# 🎉 LATEST RECORD FOUND:
#
#        Id  machineRPM                                   machineVibration  \
# 0  288884         0.0  10,1784,20,1599,30,1044,40,1172,50,1878,60,167...
#
#    needleRuntime                dateTime machineSerialNumber   status  \
# 0         2850.0 2026-03-05 09:47:54.568             0521760  Running
#
#    machineVoltageMean  machineVoltageMin  machineVoltageMax  \
# 0          230.628632         229.571945         231.816345
#
#    machineCurrentMean  machineCurrentMin  machineCurrentMax  machinePowerMean  \
# 0            4.266572           0.241119            7.07429        983.993662
#
#    machinePowerMin  machinePowerMax      epochT
# 0        55.354068      1639.936006  1772704074
#
# Pipeline test complete. Data is flowing beautifully.

# %%
import pyodbc
print(pyodbc.drivers())
